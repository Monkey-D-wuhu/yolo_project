# %%
from ultralytics import YOLO

# %%
import cv2

# %%
import torch
print("PyTorch 版本:", torch.__version__)
# Out:
# PyTorch 版本: 2.7.1+cu128

# %%
model = YOLO('yolov8n.pt')
model.train(
    data='dataset/coco.yaml',
    epochs=3,
    imgsz=640,
    batch=16,
    name='yolov8n_coco'
)
# Out:
# C:\Users\haha\.conda\envs\yolov8\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Ultralytics 8.3.168  Python-3.11.13 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %%
import torch
print("CUDA 是否可用：", torch.cuda.is_available())
if torch.cuda.is_available():
    print("使用的 GPU 名称：", torch.cuda.get_device_name(0))
    print("GPU 总数：", torch.cuda.device_count())
else:
    print("当前使用的是 CPU")
# Out:
# CUDA 是否可用： True
# 使用的 GPU 名称： NVIDIA GeForce RTX 5060 Laptop GPU
# GPU 总数： 1

# %%
from torchvision.ops import nms
import torch

boxes = torch.rand(10, 4).cuda()
scores = torch.rand(10).cuda()
nms(boxes, scores, 0.5)  # 如果不报错，说明支持 GPU
# Out:
# tensor([4, 8, 5, 7, 2, 0, 9, 3, 6, 1], device='cuda:0')

# %%
result = model('dataset/images/val2017/000000000139.jpg')
cv2.imshow('yolo',result[0].plot())
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 57
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = model('dataset/images/val2017/000000000139.jpg')
#       2 cv2.imshow('yolo',result[0].plot())
#
# File ~\.conda\envs\yolov8\Lib\site-packages\ultralytics\engine\model.py:185, in Model.__call__(self, source, stream, **kwargs)
#     156 def __call__(
#     157     self,
#     158     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     159     stream: bool = False,
#     160     **kwargs: Any,
#     161 ) -> list:
#     162     """
#     163     Alias for the predict method, enabling the model instance to be callable for predictions.
#     164
#    (...)    183         ...     print(f"Detected {len(r)} objects in image")
#     184     """
# ...
